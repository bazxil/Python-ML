# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("Load_Extension - Sheet1-checkpoint.csv")

# %%
print(data)
# Out:
#    Load (N)  Extension (mm)
# 0         5             1.2
# 1        10             2.5
# 2        15             3.7
# 3        20             4.9
# 4        25             6.1

# %%
x = data[["Load (N)"]]
y = data[["Extension (mm)"]]

# %%
plt.scatter(x,y)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
extFor55 = model.predict([[55]])
print(extFor55)
# Out:
# [[13.44]]
# C:\Users\basil\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print('Slope(m): ',model.coef_)
print('Y-Intercept: ',model.intercept_)

m = model.coef_
c =model.intercept_

print(f'The Linear Regression line equation is : y= {m[0,0]}x+{c[0]}')
# Out:
# Slope(m):  [[0.244]]
# Y-Intercept:  [0.02]
# The Linear Regression line equation is : y= 0.244x+0.019999999999999574

# %%
plt.plot(x,model.predict(x),color='red')
plt.show()
